# %%
# !pip install panel hvplot pandas

# %%
import panel as pn
pn.extension()
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='7e14e7c9-51c8-4850-a217-f7adfcd8b030'>
#   <div id="d880236a-6803-4bde-81f7-e59bab379ebb" data-root-id="7e14e7c9-51c8-4850-a217-f7adfcd8b030" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"df5df834-99ea-4bfd-9e43-1d1359682350":{"version":"3.3.4","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"7e14e7c9-51c8-4850-a217-f7adfcd8b030"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"5da3d294-d260-4d0a-9fa9-321aa65fbb70","attributes":{"plot_id":"7e14e7c9-51c8-4850-a217-f7adfcd8b030","comm_id":"542e8d7e04894704a9723d51040cce24","client_comm_id":"aca0f045249247149499c63547afcaa9"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"Any","default":"none"},{"name":"value","kind":"Any","default":null}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":" ...
#   var render_items = [{"docid":"df5df834-99ea-4bfd-9e43-1d1359682350","roots":{"7e14e7c9-51c8-4850-a217-f7adfcd8b030":"d880236a-6803-4bde-81f7-e59bab379ebb"},"root_ids":["7e14e7c9-51c8-4850-a217-f7adfcd8b030"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
import pandas as pd
import hvplot.pandas
import panel.widgets as pnw
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='d86314ab-30db-4ae3-91f6-bd4af5775d14'>
#   <div id="b2981057-4892-4409-aac3-9666422ad158" data-root-id="d86314ab-30db-4ae3-91f6-bd4af5775d14" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"6263720a-43bc-4bbc-841e-53175b3d977a":{"version":"3.3.4","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"d86314ab-30db-4ae3-91f6-bd4af5775d14"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"29a776ac-ec83-49b2-8da4-32cb533cf8ae","attributes":{"plot_id":"d86314ab-30db-4ae3-91f6-bd4af5775d14","comm_id":"6273fee469614971914093d3e1e8b2db","client_comm_id":"6594fc6991614412be1ff3e9f70e1d21"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"Any","default":"none"},{"name":"value","kind":"Any","default":null}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":" ...
#   var render_items = [{"docid":"6263720a-43bc-4bbc-841e-53175b3d977a","roots":{"d86314ab-30db-4ae3-91f6-bd4af5775d14":"b2981057-4892-4409-aac3-9666422ad158"},"root_ids":["d86314ab-30db-4ae3-91f6-bd4af5775d14"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
df = pd.read_csv("data/steinmetz_all.csv")
df = df.dropna(subset=['response_time', 'feedback_time'])

# %% [markdown]
# # Interactive Dashboards in Jupyter Notebooks
#
# As researchers, we often need to visualize and present our findings in an engaging way. While code is important for analysis, we do not always want to show it all the time as our results are often data-centric and not code-centric. Dashboards can help us interact with and explore data in real-time, highlighting important insights. In this notebook, we will explore the process of designing interactive layouts and integrating widgets in Jupyter notebooks using Panel.

# %% [markdown]
# ## Building and Arranging Dashboard Components in Jupyter
#
# Jupyter notebooks provide an excellent interactive environment for building dashboards step by step. Instead of designing the entire dashboard at once, Jupyter allows us to break the layout into smaller components and test each one individually. This is crucial because we can instantly see how each component looks and behaves right within the notebook, getting immediate feedback. Using Jupyter’s integration with Panel, we can build, test, and refine each component in an interactive way. Once all the components are working as expected, we’ll arrange them into a full layout and show how to serve the dashboard as a web app.

# %% [markdown]
# **Example** Display "Title" as it would look on the dashboard.

# %%
pane = pn.panel("Title")
pane
# Out:
# Markdown(str)

# %% [markdown]
# It is too small! Ideally we want Title of the dashboard to be big.
#
# Display Title in second level markdown heading

# %%
pane = pn.panel("## Title")
pane
# Out:
# Markdown(str)

# %% [markdown]
# We can go even larger. Display "Title" in largest markdown heading

# %%
pane = pn.panel("# Title")
pane
# Out:
# Markdown(str)

# %% [markdown]
# Now that we are happy, we can tell panel that this is one of the elements for the web app.
#
# **Example** Display "Data Analysis" with highest markdown heading and show it.

# %%
pane1 = pn.panel("# Data Analysis")
pane1
# Out:
# Markdown(str)

# %% [markdown]
# Display your name and tell panel to serve it (call in pane2)

# %%
pane2 = pn.panel("Name")
pane2
# Out:
# Markdown(str)

# %% [markdown]
# Display today's date and tell panel to serve it (call it pane3)

# %%
pane3 = pn.panel("Date")
pane3
# Out:
# Markdown(str)

# %% [markdown]
# Our definition of component need not just be one block of text, one table, or one plot. It can be a combination of them. For example, if you are sure of a combination of plots, and you only want to see different ways of arranging them, your component can be the combination of the plots and they can be tested out directly in the notebooks.
#
# **Example** Display first and last 7 rows of "Mouse", "response_time", and "feedback_time" variables side by side

# %%
data_row1 = df[["mouse", "response_time", "feedback_time"]].head(7)
data_row2 = df[["mouse", "response_time", "feedback_time"]].tail(7)
data_row = pn.Row(data_row1, data_row2)
data_row
# Out:
# Row
#     [0] DataFrame(DataFrame)
#     [1] DataFrame(DataFrame)

# %% [markdown]
# Display first and last 5 rows of "Mouse", "response_time", and "feedback_time" variables side by side

# %%
data_row1 = df[["mouse", "response_time", "feedback_time"]].head(5)
data_row2 = df[["mouse", "response_time", "feedback_time"]].tail(5)
data_row = pn.Row(data_row1, data_row2)
data_row
# Out:
# Row
#     [0] DataFrame(DataFrame)
#     [1] DataFrame(DataFrame)

# %% [markdown]
# It is still too much data to display!
#
# Display first and last 3 rows of "Mouse", "response_time", and "feedback_time" variables side by side

# %%
data_row1 = df[["mouse", "response_time", "feedback_time"]].head(3)
data_row2 = df[["mouse", "response_time", "feedback_time"]].tail(3)
data_row = pn.Row(data_row1, data_row2)
data_row
# Out:
# Row
#     [0] DataFrame(DataFrame)
#     [1] DataFrame(DataFrame)

# %% [markdown]
# This seems good but you want to test out different ways it will appear on panel. So let's just keep this `data_rows` as is and combine it later with other visual elements.
#
# Let's also test out components made from combinations of plots.
#
# **Example** Plot histogram of "response_time" and "feedback_time" arranged one on top of another.

# %%
plot_1 = df.hvplot.hist("response_time")
plot_2 = df.hvplot.hist("feedback_time")
plot = pn.Column(plot_1, plot_2)
plot
# Out:
# Column
#     [0] HoloViews(Histogram, height=300, sizing_mode='fixed', width=700)
#     [1] HoloViews(Histogram, height=300, sizing_mode='fixed', width=700)

# %% [markdown]
# We should compare this to how it would look like when arranged side-by-side.
#
# Plot histogram of "response_time" and "feedback_time" arranged side-by-side.

# %%
plot_1 = df.hvplot.hist("response_time")
plot_2 = df.hvplot.hist("feedback_time")
plot = pn.Row(plot_1, plot_2)
plot
# Out:
# Row
#     [0] HoloViews(Histogram, height=300, sizing_mode='fixed', width=700)
#     [1] HoloViews(Histogram, height=300, sizing_mode='fixed', width=700)

# %% [markdown]
# Although you decide that this looks better for your purposes, you would still like it to be a bit more descriptive. Maybe a title would help.
#
# Before adding title to both the plots, we can just test with one of them in Jupyter notebook to see how it looks.
#
# Plot histogram of "response_time" and add a title above it using pn.pane

# %%
col1 = pn.panel("#### Histograms")
col2 = df.hvplot.hist("response_time")
hist_col = pn.Column(col1, col2)
hist_col
# Out:
# Column
#     [0] Markdown(str)
#     [1] HoloViews(Histogram, height=300, sizing_mode='fixed', width=700)

# %% [markdown]
# That should be okay. Now we can add it to our histogram component.
#
# **Example** Plot histogram of "response_time" and "feedback_time" .Title it "Histograms".

# %%
col1 = pn.panel("#### Histograms")
col2 = df.hvplot.hist("response_time") + df.hvplot.hist("feedback_time")
hist_col = pn.Column(col1, col2)
hist_col
# Out:
# Column
#     [0] Markdown(str)
#     [1] HoloViews(Layout)

# %% [markdown]
# Plot box plots of "response_time" and "feedback_time". Title it "Feedback Times: Histogram".
#
# Call it by different variable (instead of `hist_col`, you can call it `box_col`)

# %%
col1 = pn.panel("#### Box Plots")
col2 = df.hvplot.box("response_time") + df.hvplot.box("feedback_time")
box_col = pn.Column(col1, col2)
box_col
# Out:
# Column
#     [0] Markdown(str)
#     [1] HoloViews(Layout)

# %% [markdown]
# Plot a bar plots of "response_time" and "feedback_time" with mouse. Title it "Bar Plots".
#
# Call it by different variable (`bar_col`)

# %%
col1 = pn.panel("#### Bar Plots")
col2 = df.hvplot.bar("mouse","response_time") + df.hvplot.bar("mouse","feedback_time")
bar_col = pn.Column(col1, col2)
bar_col
# Out:
# Column
#     [0] Markdown(str)
#     [1] HoloViews(Layout)

# %% [markdown]
# Now that we have four components `data_row`, `hist_col`, `box_col`, `bar_col`, we can arrange them in our desired layout. We can see the arrangement with show.
#
# **Example** Arrange all the four components as Rows.

# %%
row_layout = pn.Row(data_row, hist_col, box_col, bar_col)
row_layout
# Out:
# Row
#     [0] Row
#         [0] DataFrame(DataFrame)
#         [1] DataFrame(DataFrame)
#     [1] Column
#         [0] Markdown(str)
#         [1] HoloViews(Layout)
#     [2] Column
#         [0] Markdown(str)
#         [1] HoloViews(Layout)
#     [3] Column
#         [0] Markdown(str)
#         [1] HoloViews(Layout)

# %% [markdown]
# Arrange all the four components as Columns

# %%
col_layout = pn.Column(data_row, hist_col, box_col, bar_col)
col_layout
# Out:
# Column
#     [0] Row
#         [0] DataFrame(DataFrame)
#         [1] DataFrame(DataFrame)
#     [1] Column
#         [0] Markdown(str)
#         [1] HoloViews(Layout)
#     [2] Column
#         [0] Markdown(str)
#         [1] HoloViews(Layout)
#     [3] Column
#         [0] Markdown(str)
#         [1] HoloViews(Layout)

# %% [markdown]
# Arrange all the four components as Tabs

# %%
tab_layout = pn.Tabs(data_row, hist_col, box_col, bar_col)
tab_layout
# Out:
# Tabs
#     [0] Row
#         [0] DataFrame(DataFrame)
#         [1] DataFrame(DataFrame)
#     [1] Column
#         [0] Markdown(str)
#         [1] HoloViews(Layout)
#     [2] Column
#         [0] Markdown(str)
#         [1] HoloViews(Layout)
#     [3] Column
#         [0] Markdown(str)
#         [1] HoloViews(Layout)

# %% [markdown]
# You will see non descriptive tab names. To solve it:

# %%
tab_layout = pn.Tabs(
    ("Data", data_row), 
    ("Histograms", hist_col), 
    ("Box Plots", box_col), 
    ("Bar Plot", bar_col)
    )
tab_layout
# Out:
# Tabs
#     [0] Row
#         [0] DataFrame(DataFrame)
#         [1] DataFrame(DataFrame)
#     [1] Column
#         [0] Markdown(str)
#         [1] HoloViews(Layout)
#     [2] Column
#         [0] Markdown(str)
#         [1] HoloViews(Layout)
#     [3] Column
#         [0] Markdown(str)
#         [1] HoloViews(Layout)

# %% [markdown]
# If you are happy with tab layout, you can serve it with:

# %%
layout = pn.Column(pane1, pane2, pane3, tab_layout).servable();

# %%
layout.clear();

# %% [markdown]
# ## Designing Interactive Dashboards
#
# Dashboards become even more powerful when we introduce interactivity, allowing users to control and manipulate data visualizations dynamically.
# In the previous section, we explored how Jupyter's interactive features help in iteratively designing and arranging dashboard components.
#
# We began by designing each component individually, instantly viewing how it appeared directly below the code, which enabled us to fine-tune and optimize the components in real-time.
# Once satisfied with the individual pieces, we arranged them into a layout that maximized both functionality and aesthetics.
#
# This same iterative process can be applied to create fully interactive dashb We will make use of some inbuilt features of hvPlot within Panel to add some basic interactivity to practice the workflow.  a layout
# nel dashboards.
# n a layout
# out

# %% [markdown]
# Let's begin with the smallest component: A single plot
#
# **Example** Plot a histogram of 'response_time' of selected mouse and see how it appears on the dashboard

# %%
plot_1 = df.hvplot.hist('response_time', groupby='mouse')
plot = pn.Row(plot_1)
plot
# Out:
# Row
#     [0] Row
#         [0] HoloViews(DynamicMap, height=300, sizing_mode='fixed', width=700)
#         [1] WidgetBox(align=('end', 'start'))
#             [0] Select(margin=(20, 20, 20, 20), name='mouse', options=['Cori', 'Muller', ...], value='Cori', width=250)

# %% [markdown]
# Plot a histogram of 'feedback_time' of selected mouse and see how it appears on the dashboard

# %%
plot_1 = df.hvplot.hist('feedback_time', groupby='mouse')
plot = pn.Row(plot_1)
plot
# Out:
# Row
#     [0] Row
#         [0] HoloViews(DynamicMap, height=300, sizing_mode='fixed', width=700)
#         [1] WidgetBox(align=('end', 'start'))
#             [0] Select(margin=(20, 20, 20, 20), name='mouse', options=['Cori', 'Muller', ...], value='Cori', width=250)

# %% [markdown]
# Plot a scatter plot of "feedback_time" with "response_time" of selected mouse

# %%
plot_1 = df.hvplot.scatter('feedback_time', 'response_time', groupby='mouse')
plot = pn.Row(plot_1)
plot
# Out:
# Row
#     [0] Row
#         [0] HoloViews(DynamicMap, height=300, sizing_mode='fixed', width=700)
#         [1] WidgetBox(align=('end', 'start'))
#             [0] Select(margin=(20, 20, 20, 20), name='mouse', options=['Cori', 'Muller', ...], value='Cori', width=250)

# %% [markdown]
# Great! You can see how you already know how your three main visualizations would appear on panel dashboard. Let's assume you want the plots of histogram to appear together. Let's identify a visually appealing arrangement.
#
# **Example** Create a dashboard component `response_time` that plots histogram of 'reponse_time' and 'feedback_time' of selected 'mouse' one below another

# %%
plot_1 = df.hvplot.hist('response_time', groupby='mouse')
plot_2 = df.hvplot.hist('feedback_time', groupby='mouse')
response_time = pn.Column(plot_1, plot_2)
response_time
# Out:
# Column
#     [0] Row
#         [0] HoloViews(DynamicMap, height=300, sizing_mode='fixed', width=700)
#         [1] WidgetBox(align=('end', 'start'))
#             [0] Select(margin=(20, 20, 20, 20), name='mouse', options=['Cori', 'Muller', ...], value='Cori', width=250)
#     [1] Row
#         [0] HoloViews(DynamicMap, height=300, sizing_mode='fixed', width=700)
#         [1] WidgetBox(align=('end', 'start'))
#             [0] Select(margin=(20, 20, 20, 20), name='mouse', options=['Cori', 'Muller', ...], value='Cori', width=250)

# %% [markdown]
# Create a dashboard component that plots histogram of 'reponse_time' and 'feedback_time' of selected 'mouse' side-by-side

# %%
plot_1 = df.hvplot.hist('response_time', groupby='mouse')
plot_2 = df.hvplot.hist('feedback_time', groupby='mouse')
plot = pn.Row(plot_1, plot_2)
plot
# Out:
# Row
#     [0] Row
#         [0] HoloViews(DynamicMap, height=300, sizing_mode='fixed', width=700)
#         [1] WidgetBox(align=('end', 'start'))
#             [0] Select(margin=(20, 20, 20, 20), name='mouse', options=['Cori', 'Muller', ...], value='Cori', width=250)
#     [1] Row
#         [0] HoloViews(DynamicMap, height=300, sizing_mode='fixed', width=700)
#         [1] WidgetBox(align=('end', 'start'))
#             [0] Select(margin=(20, 20, 20, 20), name='mouse', options=['Cori', 'Muller', ...], value='Cori', width=250)

# %% [markdown]
# Let's assume you like this arrangement. But you also want to see if you can squeeze in the scatter plot.
#
# Create a dashboard component `viz` that plots histogram of 'reponse_time' and 'feedback_time' each of selected 'mouse' one below another and add the scatter plot below them too. Does this look appealing?

# %%
plot_1 = df.hvplot.hist('response_time', groupby='mouse')
plot_2 = df.hvplot.hist('feedback_time', groupby='mouse')
plot_3 = df.hvplot.scatter('feedback_time', 'response_time', groupby='mouse')
viz = pn.Column(plot_1, plot_2, plot_3)
viz
# Out:
# Column
#     [0] Row
#         [0] HoloViews(DynamicMap, height=300, sizing_mode='fixed', width=700)
#         [1] WidgetBox(align=('end', 'start'))
#             [0] Select(margin=(20, 20, 20, 20), name='mouse', options=['Cori', 'Muller', ...], value='Cori', width=250)
#     [1] Row
#         [0] HoloViews(DynamicMap, height=300, sizing_mode='fixed', width=700)
#         [1] WidgetBox(align=('end', 'start'))
#             [0] Select(margin=(20, 20, 20, 20), name='mouse', options=['Cori', 'Muller', ...], value='Cori', width=250)
#     [2] Row
#         [0] HoloViews(DynamicMap, height=300, sizing_mode='fixed', width=700)
#         [1] WidgetBox(align=('end', 'start'))
#             [0] Select(margin=(20, 20, 20, 20), name='mouse', options=['Cori', 'Muller', ...], value='Cori', width=250)

# %% [markdown]
# The dashboard looks a little crowded. It would help if we treated combination of histogram plots as one component and scatter plot as another.
#
# **Example** Plot the two histograms side-by-side and the scatter plot below them

# %%
plot_1 = df.hvplot.hist('response_time', groupby='mouse')
plot_2 = df.hvplot.hist('feedback_time', groupby='mouse')
plot_3 = df.hvplot.scatter('feedback_time', 'response_time', groupby='mouse')
hist = pn.Row(plot_1, plot_2) 
viz = pn.Column(hist, plot_3)
viz
# Out:
# Column
#     [0] Row
#         [0] Row
#             [0] HoloViews(DynamicMap, height=300, sizing_mode='fixed', width=700)
#             [1] WidgetBox(align=('end', 'start'))
#                 [0] Select(margin=(20, 20, 20, 20), name='mouse', options=['Cori', 'Muller', ...], value='Cori', width=250)
#         [1] Row
#             [0] HoloViews(DynamicMap, height=300, sizing_mode='fixed', width=700)
#             [1] WidgetBox(align=('end', 'start'))
#                 [0] Select(margin=(20, 20, 20, 20), name='mouse', options=['Cori', 'Muller', ...], value='Cori', width=250)
#     [1] Row
#         [0] HoloViews(DynamicMap, height=300, sizing_mode='fixed', width=700)
#         [1] WidgetBox(align=('end', 'start'))
#             [0] Select(margin=(20, 20, 20, 20), name='mouse', options=['Cori', 'Muller', ...], value='Cori', width=250)

# %% [markdown]
# Plot the two histograms side-by-side and the scatter plot above them

# %%
plot_1 = df.hvplot.hist('response_time', groupby='mouse')
plot_2 = df.hvplot.hist('feedback_time', groupby='mouse')
plot_3 = df.hvplot.scatter('feedback_time', 'response_time', groupby='mouse')
hist = pn.Row(plot_1, plot_2) 
viz = pn.Column(plot_3, hist)
viz
# Out:
# Column
#     [0] Row
#         [0] HoloViews(DynamicMap, height=300, sizing_mode='fixed', width=700)
#         [1] WidgetBox(align=('end', 'start'))
#             [0] Select(margin=(20, 20, 20, 20), name='mouse', options=['Cori', 'Muller', ...], value='Cori', width=250)
#     [1] Row
#         [0] Row
#             [0] HoloViews(DynamicMap, height=300, sizing_mode='fixed', width=700)
#             [1] WidgetBox(align=('end', 'start'))
#                 [0] Select(margin=(20, 20, 20, 20), name='mouse', options=['Cori', 'Muller', ...], value='Cori', width=250)
#         [1] Row
#             [0] HoloViews(DynamicMap, height=300, sizing_mode='fixed', width=700)
#             [1] WidgetBox(align=('end', 'start'))
#                 [0] Select(margin=(20, 20, 20, 20), name='mouse', options=['Cori', 'Muller', ...], value='Cori', width=250)

# %% [markdown]
# Plot the two histograms side-by-side and the scatter plot in separate tabs

# %%
plot_1 = df.hvplot.hist('response_time', groupby='mouse')
plot_2 = df.hvplot.hist('feedback_time', groupby='mouse')
plot_3 = df.hvplot.scatter('feedback_time', 'response_time', groupby='mouse')
hist = pn.Row(plot_1, plot_2) 
viz = pn.Tabs(
    ("Histograms", hist), 
    ("Scatter Plot", plot_3)
)
viz
# Out:
# Tabs
#     [0] Row
#         [0] Row
#             [0] HoloViews(DynamicMap, height=300, sizing_mode='fixed', width=700)
#             [1] WidgetBox(align=('end', 'start'))
#                 [0] Select(margin=(20, 20, 20, 20), name='mouse', options=['Cori', 'Muller', ...], value='Cori', width=250)
#         [1] Row
#             [0] HoloViews(DynamicMap, height=300, sizing_mode='fixed', width=700)
#             [1] WidgetBox(align=('end', 'start'))
#                 [0] Select(margin=(20, 20, 20, 20), name='mouse', options=['Cori', 'Muller', ...], value='Cori', width=250)
#     [1] Row
#         [0] HoloViews(DynamicMap, height=300, name='Scatter Plot', sizing_mode='fixed', width=700)
#         [1] WidgetBox(align=('end', 'start'))
#             [0] Select(margin=(20, 20, 20, 20), name='mouse', options=['Cori', 'Muller', ...], value='Cori', width=250)

# %%
layout = viz.servable();

# %%
layout.clear()

# %% [markdown]
# ## Getting More Control over Interactive Widgets
#
# In the previous section, we used panel only for arrangement of our interactive visual components. The interactive options from hvplot alone can be quite limited. However, panel also provides interactive widgets that can be combined with hvplot figures to give us more control over the kind of interactive widgets that can be used for the dashboard. And as always, they can be tried and tested out in Jupyter notebook before implementing as web app.
#
# In this section, we will follow the similar approach as the other two sections where we will test out single visualization, smaller combinations, and a larger layout but by adding more interactive options using panel.

# %% [markdown]
# One of the requirements of your dashboard is that your collaborators has an option to see a certain number of rows of your data. So let's try out a few of them and see which one would look best on a dashboard.
#
# **Example** use a slider to start from no rows to full length of dataset

# %%
interactive_df = df.interactive()
slider = pnw.IntSlider(name='Num Rows', start=0, end=len(df))
table = interactive_df.head(slider)
table
# Out:
# <div id='c7a4b9d0-ae42-4786-9e1b-ecc332198ef5'>
#   <div id="b607331f-9352-4d3b-97ea-20570c2b7143" data-root-id="c7a4b9d0-ae42-4786-9e1b-ecc332198ef5" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"23b4b0f4-df39-46a9-b7f1-20d62fa69be3":{"version":"3.3.4","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"c7a4b9d0-ae42-4786-9e1b-ecc332198ef5","attributes":{"name":"Row07335","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"51e34f0f-f2d2-49bc-8119-f9e3c574efa3","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.8/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"405f6b90-2b8c-4836-b77e-c474c4c1a151","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.8/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"87be0e48-d308-40cb-a91d-5a0fe0dd53bc","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.8/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"6057f9c4-afe2-45c1-9b37-161e3fe32c82","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.8/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"e5158c3c-c44f-4942-972a-ccbbf069e3e2","attributes":{"name":"Column07334","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"51e34f0f-f2d2-49bc-8119-f9e3c574efa3"},{"id":"405f6b90-2b8c-4836-b77e-c474c4c1a151"},{"id":"87be0e48-d308-40cb-a91d-5a0fe0dd53bc"},{"id":"6057f9c4-afe2-45c1-9b37-161e3fe32c82"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"211d1501-698b-4a44-9c3c-a4ab140c41dc","attributes":{"name":"Column07326","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"51e34f0f-f2d2-49bc-8119-f9e3c574efa3"},{"id":"405f6b90-2b8c-4836-b77e-c474c4c1a151"},{"id":"87be0e48-d308-40cb-a91d-5a0fe0dd53bc"},{"id":"6057f9c4-afe2-45c1-9b37-161e3fe32c82"}],"margin":0,"align":"start","children":[{"type":"object","name":"Slider","id":"bf364597-37f7-46c8-956e-4000e02d28d1","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":
attributes":{"url":"https://cdn.holoviz.org/panel/1.3.8/dist/css/dataframe.css"}},{"id":"974c910b-7668-4e8a-b495-1bb81ac79a53"},{"id":"1f67fbe2-9b81-4ad0-afd3-23fe557f33f6"}],"margin":[5,10],"align":"start","text":"&lt;table class=&quot;dataframe panel ...

# %% [markdown]
# It looks empty starting from 0 and 100 is too many rows.
#
# Use a slider to start from 3 rows to a maximum of 10 rows.

# %%
interactive_df = df.interactive()
slider = pnw.IntSlider(name='Num Rows', start=3, end=10)
table = interactive_df.head(slider)
table
# Out:
# <div id='68b1ddf0-7980-4eb9-857f-1a81a7fac894'>
#   <div id="bc9703cd-59fc-4619-9a4b-e34b5e9bcdd5" data-root-id="68b1ddf0-7980-4eb9-857f-1a81a7fac894" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"518f132f-a5e6-41e7-b139-2cb3ea041f07":{"version":"3.3.4","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"68b1ddf0-7980-4eb9-857f-1a81a7fac894","attributes":{"name":"Row07593","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"37026fc0-50cb-4ebe-bf9a-82cd9811c5bc","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.8/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"7dbdd9c0-a89c-41c3-a67e-af069daf531f","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.8/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"90582e7f-9145-4b54-a12f-b68d0c2b5d86","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.8/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"7dbaccb4-be85-4921-af44-7509586d0b3a","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.8/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"687e7591-73fb-44ec-84d6-b680a6ec4f46","attributes":{"name":"Column07592","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"37026fc0-50cb-4ebe-bf9a-82cd9811c5bc"},{"id":"7dbdd9c0-a89c-41c3-a67e-af069daf531f"},{"id":"90582e7f-9145-4b54-a12f-b68d0c2b5d86"},{"id":"7dbaccb4-be85-4921-af44-7509586d0b3a"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"e64c6db2-a6fa-418c-857b-cca1688b52f7","attributes":{"name":"Column07584","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"37026fc0-50cb-4ebe-bf9a-82cd9811c5bc"},{"id":"7dbdd9c0-a89c-41c3-a67e-af069daf531f"},{"id":"90582e7f-9145-4b54-a12f-b68d0c2b5d86"},{"id":"7dbaccb4-be85-4921-af44-7509586d0b3a"}],"margin":0,"align":"start","children":[{"type":"object","name":"Slider","id":"c2147ebe-0d5c-4c02-bc17-a092aa85d390","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"37026fc0-50cb-4ebe-bf9a-82cd9811c5bc"},{"id":"90582e7f-9145-4b54-a12f-b68d0c2b5d86"},{"id":"7dbaccb4-be85-4921-af44-7509586d0b3a"}],"margin":[5,10],"align":"start","title":"Num Rows","start":3,"end":10,"value":3}}]}},{"type":"object","name":"panel.models.layout.Column","id":"17debae7-ed9f-4b76-af72-726e0c596c48","attributes":{"name":"Column07589","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"37026fc0-50cb-4ebe-bf9a-82cd9811c5bc"},{"id":"7dbdd9c0-a89c-41c3-a67e-af069daf531f"},{"id":"90582e7f-9145-4b54-a12f-b68d0c2b5d86"},{"id":"7dbaccb4-be85-4921-af44-7509586d0b3a"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.markup.HTML","id":"84c62d8a-27f4-4846-b19e-10b607a198f5","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"37026fc0-50cb-4ebe-bf9a-82cd9811c5bc"},{"type":"object","name":"ImportedStyleSheet","id":"801c3e1c-da5a-4a3b-873d-5c59dc3ae0c7","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.8/dist/css/dataframe.css"}},{"id":"90582e7f-9145-4b54-a12f-b68d0c2b5d86"},{"id":"7dbaccb4-be85-4921-af44-7509586d0b3a"}],"margin":[5,10],"align":"start","text":"&lt;table class=&quot;dataframe panel- ...

# %% [markdown]
# Now you want to display statistics of response_time or feedback_time. What you are unsure of is how to display the choices. Let's try them out
#
# **Example** Display the options as select box

# %%
interactive_df = df.interactive()
select = pnw.Select(name='Select', options=['response_time','feedback_time'])
stats = interactive_df[select].describe()
stats
# Out:
# <div id='f2d6444a-1a4c-4df8-bd1f-14ad854db7ae'>
#   <div id="ac38281e-437a-41b2-b45f-1f7cf9288a04" data-root-id="f2d6444a-1a4c-4df8-bd1f-14ad854db7ae" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"852ddeee-d438-4553-8e5f-5a1523648161":{"version":"3.3.4","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":
stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"19ed3d24-abe6-446c-9854-a66d96af5f17"},{"id":"32058c98-27e7-4ce6-9377-b10d7e088196"},{"id":"1e9c8212-a190-43ff-bafa-da19abb3571e"},{"id":"0c7b278f-70d2-48ea-a5aa-7297d7346a8e"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"7cbe9bae-a6c4-4dfc-91f8-00a3c48e3918","attributes":{"name":"Column07826","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"19ed3d24-abe6-446c-9854-a66d96af5f17"},{"id":"32058c98-27e7-4ce6-9377-b10d7e088196"},{"id":"1e9c8212-a190-43ff-bafa-da19abb3571e"},{"id":"0c7b278f-70d2-48ea-a5aa-7297d7346a8e"}],"margin":0,"align":"start","children":[{"type":"object","name":"Div","id":"6acd8aca-094d-4114-bfaa-a9f7591064c4","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"19ed3d24-abe6-446c-9854-a66d96af5f17"},{"id":"1e9c8212-a190-43ff-bafa-da19abb3571e"},{"id":"0c7b278f-70d2-48ea-a5aa-7297d7346a8e"}],"margin":[5,0,0,10],"align":"start","text":"Select: <b>response_time</b>"}},{"type":"object","name":"Slider","id":"0ddefcb1-1eac-4a95-b136-b253387c56fc","attributes":{"js_property_callbacks":{"type":"map","entries":[["change:value",[{"type":"object","name":"CustomJS","id":"c960cfb8-ee2f-4b5f-8f9d-30e30db24c2f","attributes":{"tags":[[1630524797840,[null,"value"],[null,null]]],"args":{"type":"map","entries":[["bidirectional",false],["properties",{"type":"map"}],["source",{"id":"0ddefcb1-1eac-4a95-b136-b253387c56fc"}],["target",{"id":"6acd8aca-094d-4114-bfaa-a9f7591064c4"}]]},"code":"try { \n    var labels = ['Select: <b>response_time</b>', 'Select: <b>feedback_time</b>']\n    target.text = labels[source.value]\n     } catch(err) { console.log(err) }"}}]]]},"stylesheets": ...

# %% [markdown]
# That does not look suitable for this purpose.
#
# Display the options as radio buttons

# %%
interactive_df = df.interactive()
radio_button_group = pnw.RadioButtonGroup(name='Select', options=['response_time', 'feedback_time'])
stats = interactive_df[radio_button_group].describe()
stats
# Out:
# <div id='b7658ea2-33b1-4bda-891d-ff7e6d481a3c'>
#   <div id="bf24a845-3274-453a-a1b7-d9f3719a5d40" data-root-id="b7658ea2-33b1-4bda-891d-ff7e6d481a3c" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"302c4ac5-1402-4f73-a6bd-22abc9c9fcc2":{"version":"3.3.4","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"b7658ea2-33b1-4bda-891d-ff7e6d481a3c","attributes":{"name":"Row08118","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"8930ecc5-8e97-4948-91bf-b0d3991f5bb3","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.8/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"be19e303-710a-4c5b-b0f8-98dbbe73863a","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.8/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"9ade592d-c263-45a9-a291-fa20ba29d2b5","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.8/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"9a634dc0-4b8b-49db-a8ba-13618532a826","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.8/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"8c5d94fe-9020-4db9-ab4c-e16c3982f650","attributes":{"name":"Column08117","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"8930ecc5-8e97-4948-91bf-b0d3991f5bb3"},{"id":"be19e303-710a-4c5b-b0f8-98dbbe73863a"},{"id":"9ade592d-c263-45a9-a291-fa20ba29d2b5"},{"id":"9a634dc0-4b8b-49db-a8ba-13618532a826"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"548a9a81-2cbd-462a-a251-65a0b6f5fe28","attributes":{"name":"Column08109","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"8930ecc5-8e97-4948-91bf-b0d3991f5bb3"},{"id":"be19e303-710a-4c5b-b0f8-98dbbe73863a"},{"id":"9ade592d-c263-45a9-a291-fa20ba29d2b5"},{"id":"9a634dc0-4b8b-49db-a8ba-13618532a826"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.widgets.RadioButtonGroup","id":"a2299b31-7c29-4bb6-bb49-d631b81d94a5","attributes":{"css_classes":["solid"],"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"8930ecc5-8e97-4948-91bf-b0d3991f5bb3"},{"type":"object","name":"ImportedStyleSheet","id":"7c2191d7-686f-49ee-9004-69eb972eabed","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.8/dist/css/button.css"}},{"id":"9ade592d-c263-45a9-a291-fa20ba29d2b5"},{"id":"9a634dc0-4b8b-49db-a8ba-13618532a826"}],"margin":[5,10],"align":"start","labels":["response_time","feedback_time"],"active":0}}]}},{"type":"object","name":"panel.models.layout.Column","id":"59878f3d-7927-4079-8af2-8f846f27ef72","attributes":{"name":"Column08114","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"8930ecc5-8e97-4948-91bf-b0d3991f5bb3"},{"id":"be19e303-710a-4c5b-b0f8-98dbbe73863a"},{"id":"9ade592d-c263-45a9-a291-fa20ba29d2b5"},{"id":"9a634dc0-4b8b-49db-a8ba-13618532a826"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.markup.HTML","id":"2907d590-47c4-40b1-a14c-9ee82618f015","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"8930ecc5-8e97-4948-91bf-b0d3991f5bb3"},{"type":"object","name":"ImportedStyleSheet","id":"1a2fbca7-5d69-4bb4-9b11-10b2a20d3406","attributes":{"url":"htt ...

# %% [markdown]
# Now only figures are remaining. You need to arrange all these in a layout along with box plots when response time or feedback time are selected. Let's try out as usual, different ways of arranging them.
#
# **Example** Arrange data, stats, and plot side by side

# %%
interactive_df = df.interactive()
slider = pnw.IntSlider(name='Num Rows', start=3, end=10)
radio_button_group = pnw.RadioButtonGroup(name='Select', options=['response_time', 'feedback_time'])
table = interactive_df.head(slider)
stats = interactive_df[radio_button_group].describe()
plot = interactive_df[radio_button_group].hvplot.box()

layout = pn.Row(table, stats, plot)
layout
# Out:
# Row
#     [0] Interactive(Interactive)
#     [1] Interactive(Interactive)
#     [2] Interactive(Interactive)

# %% [markdown]
# Arrange them one above the other

# %%
interactive_df = df.interactive()
slider = pnw.IntSlider(name='Num Rows', start=3, end=10)
radio_button_group = pnw.RadioButtonGroup(name='Select', options=['response_time', 'feedback_time'])
table = interactive_df.head(slider)
stats = interactive_df[radio_button_group].describe()
plot = interactive_df[radio_button_group].hvplot.box()

layout = pn.Column(table, stats, plot)
layout
# Out:
# Column
#     [0] Interactive(Interactive)
#     [1] Interactive(Interactive)
#     [2] Interactive(Interactive)

# %% [markdown]
# Arrange the table one top and both the plot and stats on the bottom row

# %%
interactive_df = df.interactive()
slider = pnw.IntSlider(name='Num Rows', start=3, end=10)
radio_button_group = pnw.RadioButtonGroup(name='Select', options=['response_time', 'feedback_time'])
table = interactive_df.head(slider)
stats = interactive_df[radio_button_group].describe()
plot = interactive_df[radio_button_group].hvplot.box()

layout = pn.Column(table, pn.Row(stats, plot))
layout
# Out:
# Column
#     [0] Interactive(Interactive)
#     [1] Row
#         [0] Interactive(Interactive)
#         [1] Interactive(Interactive)

# %% [markdown]
# Serve it in web app and see the whole thing

# %%
layout.servable();

# %%
layout.clear()
# Out:
# [Interactive(Interactive),
#  Row
#      [0] Interactive(Interactive)
#      [1] Interactive(Interactive)]

# %% [markdown]
# ## Panel has many other widgets (Demo)

# %% [markdown]
# With check box

# %%
# Define widgets
checkbox = pn.widgets.Checkbox(name='Line Plot', value=True)

@pn.depends(checkbox.param.value)
def checkbox_plot(value):
    plot_type = 'line' if value else 'scatter'
    return df.hvplot(x='response_time', y='feedback_time', kind=plot_type).opts(title=f"Line Plot? {value}")

layout = pn.Row(checkbox, checkbox_plot)
layout

# %%
checkbox = pn.widgets.Checkbox(name='Color red', value=True)

@pn.depends(checkbox.param.value)
def checkbox_plot(value):
    color = 'r' if value else 'b'
    plot1 = df.hvplot(x='response_time', y='feedback_time', kind='scatter', color=color).opts(title=f"Color Red? {value}")
    plot2 = df.hvplot(x='response_time', y='reaction_time', kind='scatter', color=color).opts(title=f"Color Red? {value}")
    return (plot1 + plot2).opts(shared_axes=False)

layout = pn.Row(checkbox, checkbox_plot)
layout
