# %%
# !pip install panel hvplot pandas

# %%
import panel as pn
pn.extension()
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='42f1838b-c750-46c6-a30f-099c87beb471'>
#   <div id="e25c9030-afad-4367-931d-a06ef8daca59" data-root-id="42f1838b-c750-46c6-a30f-099c87beb471" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"741bf2b8-008f-4e1a-8878-cf943b0d4f3f":{"version":"3.3.4","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"42f1838b-c750-46c6-a30f-099c87beb471"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"0e824a7d-d9f4-441b-a6ff-74908d08308d","attributes":{"plot_id":"42f1838b-c750-46c6-a30f-099c87beb471","comm_id":"d937da3f9927400397e376b3827f54ad","client_comm_id":"eebd290e604b4de98062c3ab0309fb53"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"Any","default":"none"},{"name":"value","kind":"Any","default":null}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":" ...
#   var render_items = [{"docid":"741bf2b8-008f-4e1a-8878-cf943b0d4f3f","roots":{"42f1838b-c750-46c6-a30f-099c87beb471":"e25c9030-afad-4367-931d-a06ef8daca59"},"root_ids":["42f1838b-c750-46c6-a30f-099c87beb471"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
import pandas as pd
import hvplot.pandas
import panel.widgets as pnw
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='7f8ddbb7-301a-4aca-9c42-83a9515792d9'>
#   <div id="e4fade8f-8d63-45af-a7e4-8bfce2f9766f" data-root-id="7f8ddbb7-301a-4aca-9c42-83a9515792d9" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"b4595bf9-4c98-4640-a3b7-10eceae4f3a2":{"version":"3.3.4","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"7f8ddbb7-301a-4aca-9c42-83a9515792d9"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"6f4cc133-8a24-4ed4-ad88-bc6a41e40202","attributes":{"plot_id":"7f8ddbb7-301a-4aca-9c42-83a9515792d9","comm_id":"921704c9fa864991a9b82ff8ae214857","client_comm_id":"03c9df3bc2f7446ba36da3858ca2c1cc"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"Any","default":"none"},{"name":"value","kind":"Any","default":null}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":" ...
#   var render_items = [{"docid":"b4595bf9-4c98-4640-a3b7-10eceae4f3a2","roots":{"7f8ddbb7-301a-4aca-9c42-83a9515792d9":"e4fade8f-8d63-45af-a7e4-8bfce2f9766f"},"root_ids":["7f8ddbb7-301a-4aca-9c42-83a9515792d9"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
df = pd.read_csv("data/steinmetz_all.csv")
df = df.dropna(subset=['response_time', 'feedback_time'])

# %% [markdown]
# # Interactive Dashboards in Jupyter Notebooks
#
# As researchers, we often need to visualize and present our findings in an engaging way. While code is important for analysis, we do not always want to show it all the time as our results are often data-centric and not code-centric. Dashboards can help us interact with and explore data in real-time, highlighting important insights. In this notebook, we will explore the process of designing interactive layouts and integrating widgets in Jupyter notebooks using Panel.

# %% [markdown]
# ### Motivating Example: hvplot.explorer()

# %% [markdown]
# ## Building and Arranging Dashboard Components in Jupyter
#
# Jupyter notebooks provide an excellent interactive environment for building dashboards step by step. Instead of designing the entire dashboard at once, Jupyter allows us to break the layout into smaller components and test each one individually. This is crucial because we can instantly see how each component looks and behaves right within the notebook, getting immediate feedback. Using Jupyter’s integration with Panel, we can build, test, and refine each component in an interactive way. Once all the components are working as expected, we’ll arrange them into a full layout and show how to serve the dashboard as a web app.

# %% [markdown]
# **Example** Display "Title" as it would look on the dashboard.

# %%
pane = pn.panel("Title")
pane
# Out:
# Markdown(str)

# %% [markdown]
# It is too small! Ideally we want Title of the dashboard to be big.
#
# Display Title in second level markdown heading

# %%
pane = pn.panel("## Title")
pane
# Out:
# Markdown(str)

# %% [markdown]
# We can go even larger. Display "Title" in largest markdown heading

# %%
pane = pn.panel("# Title")
pane
# Out:
# Markdown(str)

# %% [markdown]
# Now that we are happy, we can tell panel that this is one of the elements for the web app.
#
# **Example** Display "Data Analysis" with highest markdown heading and tell panel to serve it.
#
# Hint: Preview the app on the side by clicking on `Preview With Panel`
#
# ![panel](img/panel.png)

# %%
pane1 = pn.panel("# Data Analysis")
pane1.servable();

# %% [markdown]
# Display your name and tell panel to serve it (call in pane2)

# %%
pane2 = pn.panel("Name")
pane2.servable();

# %% [markdown]
# Display today's date and tell panel to serve it (call it pane3)

# %%
pane3 = pn.panel("Date")
pane3.servable();

# %% [markdown]
# Our definition of component need not just be one block of text, one table, or one plot. It can be a combination of them. For example, if you are sure of a combination of plots, and you only want to see different ways of arranging them, your component can be the combination of the plots and they can be tested out directly in the notebooks.
#
# **Example** Display first and last 7 rows of "Mouse", "response_time", and "feedback_time" variables side by side

# %%
data_row1 = df[["mouse", "response_time", "feedback_time"]].head(7)
data_row2 = df[["mouse", "response_time", "feedback_time"]].tail(7)
data_row = pn.Row(data_row1, data_row2)
data_row
# Out:
# Row
#     [0] DataFrame(DataFrame)
#     [1] DataFrame(DataFrame)

# %% [markdown]
# Display first and last 5 rows of "Mouse", "response_time", and "feedback_time" variables side by side

# %%
data_row1 = df[["mouse", "response_time", "feedback_time"]].head(5)
data_row2 = df[["mouse", "response_time", "feedback_time"]].tail(5)
data_row = pn.Row(data_row1, data_row2)
data_row
# Out:
# Row
#     [0] DataFrame(DataFrame)
#     [1] DataFrame(DataFrame)

# %% [markdown]
# It is still too much data to display!
#
# Display first and last 3 rows of "Mouse", "response_time", and "feedback_time" variables side by side

# %%
data_row1 = df[["mouse", "response_time", "feedback_time"]].head(3)
data_row2 = df[["mouse", "response_time", "feedback_time"]].tail(3)
data_row = pn.Row(data_row1, data_row2)
data_row
# Out:
# Row
#     [0] DataFrame(DataFrame)
#     [1] DataFrame(DataFrame)

# %% [markdown]
# This seems good but you want to test out different ways it will appear on panel. So let's just keep this `data_rows` as is and combine it later with other visual elements.
#
# Let's also test out components made from combinations of plots.
#
# **Example** Plot histogram of "response_time" and "feedback_time" arranged one on top of another.

# %%
plot_1 = df.hvplot.hist("response_time")
plot_2 = df.hvplot.hist("feedback_time")
plot = pn.Column(plot_1, plot_2)
plot
# Out:
# Column
#     [0] HoloViews(Histogram, height=300, sizing_mode='fixed', width=700)
#     [1] HoloViews(Histogram, height=300, sizing_mode='fixed', width=700)

# %% [markdown]
# We should compare this to how it would look like when arranged side-by-side.
#
# Plot histogram of "response_time" and "feedback_time" arranged side-by-side.

# %%
plot_1 = df.hvplot.hist("response_time")
plot_2 = df.hvplot.hist("feedback_time")
plot = pn.Row(plot_1, plot_2)
plot
# Out:
# Row
#     [0] HoloViews(Histogram, height=300, sizing_mode='fixed', width=700)
#     [1] HoloViews(Histogram, height=300, sizing_mode='fixed', width=700)

# %% [markdown]
# Although you decide that this looks better for your purposes, you would still like it to be a bit more descriptive. Maybe a title would help.
#
# Before adding title to both the plots, we can just test with one of them in Jupyter notebook to see how it looks.
#
# Plot histogram of "response_time" and add a title above it using pn.pane

# %%
col1 = pn.panel("#### Histograms")
col2 = df.hvplot.hist("response_time")
hist_col = pn.Column(col1, col2)
hist_col
# Out:
# Column
#     [0] Markdown(str)
#     [1] HoloViews(Histogram, height=300, sizing_mode='fixed', width=700)

# %% [markdown]
# That should be okay. Now we can add it to our histogram component.
#
# **Example** Plot histogram of "response_time" and "feedback_time" .Title it "Histograms".

# %%
col1 = pn.panel("#### Histograms")
col2 = df.hvplot.hist("response_time") + df.hvplot.hist("feedback_time")
hist_col = pn.Column(col1, col2)
hist_col
# Out:
# Column
#     [0] Markdown(str)
#     [1] HoloViews(Layout)

# %% [markdown]
# Plot box plots of "response_time" and "feedback_time". Title it "Feedback Times: Histogram".
#
# Call it by different variable (instead of `hist_col`, you can call it `box_col`)

# %%
col1 = pn.panel("#### Box Plots")
col2 = df.hvplot.box("response_time") + df.hvplot.box("feedback_time")
box_col = pn.Column(col1, col2)
box_col
# Out:
# Column
#     [0] Markdown(str)
#     [1] HoloViews(Layout)

# %% [markdown]
# Plot a bar plots of "response_time" and "feedback_time" with mouse. Title it "Bar Plots".
#
# Call it by different variable (`bar_col`)

# %%
col1 = pn.panel("#### Bar Plots")
col2 = df.hvplot.bar("mouse","response_time") + df.hvplot.bar("mouse","feedback_time")
bar_col = pn.Column(col1, col2)
bar_col
# Out:
# Column
#     [0] Markdown(str)
#     [1] HoloViews(Layout)

# %% [markdown]
# Now that we have four components `data_row`, `hist_col`, `box_col`, `bar_col`, we can arrange them in our desired layout. We can see the arrangement with show.
#
# **Example** Arrange all the four components as Rows.

# %%
row_layout = pn.Row(data_row, hist_col, box_col, bar_col)
row_layout
# Out:
# Row
#     [0] Row
#         [0] DataFrame(DataFrame)
#         [1] DataFrame(DataFrame)
#     [1] Column
#         [0] Markdown(str)
#         [1] HoloViews(Layout)
#     [2] Column
#         [0] Markdown(str)
#         [1] HoloViews(Layout)
#     [3] Column
#         [0] Markdown(str)
#         [1] HoloViews(Layout)

# %% [markdown]
# Arrange all the four components as Columns

# %%
col_layout = pn.Column(data_row, hist_col, box_col, bar_col)
col_layout.show();
# Out:
# Launching server at http://localhost:60820

# %% [markdown]
# Arrange all the four components as Tabs

# %%
tab_layout = pn.Tabs(data_row, hist_col, box_col, bar_col)
tab_layout.show();
# Out:
# Launching server at http://localhost:60976
# WARNING:bokeh.server.views.ws:Failed sending message as connection was closed

# %% [markdown]
# You will see non descriptive tab names. To solve it:

# %%
tab_layout = pn.Tabs(
    ("Data", data_row), 
    ("Histograms", hist_col), 
    ("Box Plots", box_col), 
    ("Bar Plot", bar_col)
    )
tab_layout.show();
# Out:
# Launching server at http://localhost:61317

# %% [markdown]
# If you are happy with tab layout, you can serve it with:

# %%
pn.serve(pn.Column(pane1, pane2, pane3, tab_layout));
# Out:
# Launching server at http://localhost:62550

# %% [markdown]
# ## Designing Interactive Dashboards
#
# Dashboards become even more powerful when we introduce interactivity, allowing users to control and manipulate data visualizations dynamically.
# In the previous section, we explored how Jupyter's interactive features help in iteratively designing and arranging dashboard components.
#
# We began by designing each component individually, instantly viewing how it appeared directly below the code, which enabled us to fine-tune and optimize the components in real-time.
# Once satisfied with the individual pieces, we arranged them into a layout that maximized both functionality and aesthetics.
#
# This same iterative process can be applied to create fully interactive dashb We will make use of some inbuilt features of hvPlot within Panel to add some basic interactivity to practice the workflow.  a layout
# nel dashboards.
# n a layout
# out

# %% [markdown]
# Let's begin with the smallest component: A single plot
#
# **Example** Plot a histogram of 'response_time' of selected mouse and see how it appears on the dashboard

# %%
plot_1 = df.hvplot.hist('response_time', groupby='mouse')
plot = pn.Row(plot_1)
plot
# Out:
# Row
#     [0] Row
#         [0] HoloViews(DynamicMap, height=300, sizing_mode='fixed', width=700)
#         [1] WidgetBox(align=('end', 'start'))
#             [0] Select(margin=(20, 20, 20, 20), name='mouse', options=['Cori', 'Muller', ...], value='Cori', width=250)

# %% [markdown]
# Plot a histogram of 'feedback_time' of selected mouse and see how it appears on the dashboard

# %%
plot_1 = df.hvplot.hist('feedback_time', groupby='mouse')
plot = pn.Row(plot_1)
plot
# Out:
# Row
#     [0] Row
#         [0] HoloViews(DynamicMap, height=300, sizing_mode='fixed', width=700)
#         [1] WidgetBox(align=('end', 'start'))
#             [0] Select(margin=(20, 20, 20, 20), name='mouse', options=['Cori', 'Muller', ...], value='Cori', width=250)

# %% [markdown]
# Plot a scatter plot of "feedback_time" with "response_time" of selected mouse

# %%
plot_1 = df.hvplot.scatter('feedback_time', 'response_time', groupby='mouse')
plot = pn.Row(plot_1)
plot
# Out:
# Row
#     [0] Row
#         [0] HoloViews(DynamicMap, height=300, sizing_mode='fixed', width=700)
#         [1] WidgetBox(align=('end', 'start'))
#             [0] Select(margin=(20, 20, 20, 20), name='mouse', options=['Cori', 'Muller', ...], value='Cori', width=250)

# %% [markdown]
# Great! You can see how you already know how your three main visualizations would appear on panel dashboard. Let's assume you want the plots of histogram to appear together. Let's identify a visually appealing arrangement.
#
# **Example** Create a dashboard component `response_time` that plots histogram of 'reponse_time' and 'feedback_time' of selected 'mouse' one below another

# %%
plot_1 = df.hvplot.hist('response_time', groupby='mouse')
plot_2 = df.hvplot.hist('feedback_time', groupby='mouse')
response_time = pn.Column(plot_1, plot_2)
response_time
# Out:
# Row
#     [0] Row
#         [0] HoloViews(DynamicMap, height=300, sizing_mode='fixed', width=700)
#         [1] WidgetBox(align=('end', 'start'))
#             [0] Select(margin=(20, 20, 20, 20), name='mouse', options=['Cori', 'Muller', ...], value='Cori', width=250)
#     [1] Row
#         [0] HoloViews(DynamicMap, height=300, sizing_mode='fixed', width=700)
#         [1] WidgetBox(align=('end', 'start'))
#             [0] Select(margin=(20, 20, 20, 20), name='mouse', options=['Cori', 'Muller', ...], value='Cori', width=250)

# %% [markdown]
# Create a dashboard component that plots histogram of 'reponse_time' and 'feedback_time' of selected 'mouse' side-by-side

# %%
plot_1 = df.hvplot.hist('response_time', groupby='mouse')
plot_2 = df.hvplot.hist('feedback_time', groupby='mouse')
plot = pn.Row(plot_1, plot_2)
plot
# Out:
# Column
#     [0] Row
#         [0] HoloViews(DynamicMap, height=300, sizing_mode='fixed', width=700)
#         [1] WidgetBox(align=('end', 'start'))
#             [0] Select(margin=(20, 20, 20, 20), name='mouse', options=['Cori', 'Muller', ...], value='Cori', width=250)
#     [1] Row
#         [0] HoloViews(DynamicMap, height=300, sizing_mode='fixed', width=700)
#         [1] WidgetBox(align=('end', 'start'))
#             [0] Select(margin=(20, 20, 20, 20), name='mouse', options=['Cori', 'Muller', ...], value='Cori', width=250)

# %% [markdown]
# Let's assume you like this arrangement. But you also want to see if you can squeeze in the scatter plot.
#
# Create a dashboard component `viz` that plots histogram of 'reponse_time' and 'feedback_time' each of selected 'mouse' one below another and add the scatter plot below them too. Does this look appealing?

# %%
plot_1 = df.hvplot.hist('response_time', groupby='mouse')
plot_2 = df.hvplot.hist('feedback_time', groupby='mouse')
plot_3 = df.hvplot.scatter('feedback_time', 'response_time', groupby='mouse')
viz = pn.Column(plot_1, plot_2, plot_3)
viz
# Out:
# Column
#     [0] Row
#         [0] HoloViews(DynamicMap, height=300, sizing_mode='fixed', width=700)
#         [1] WidgetBox(align=('end', 'start'))
#             [0] Select(margin=(20, 20, 20, 20), name='mouse', options=['Cori', 'Muller', ...], value='Cori', width=250)
#     [1] Row
#         [0] HoloViews(DynamicMap, height=300, sizing_mode='fixed', width=700)
#         [1] WidgetBox(align=('end', 'start'))
#             [0] Select(margin=(20, 20, 20, 20), name='mouse', options=['Cori', 'Muller', ...], value='Cori', width=250)
#     [2] Row
#         [0] HoloViews(DynamicMap, height=300, sizing_mode='fixed', width=700)
#         [1] WidgetBox(align=('end', 'start'))
#             [0] Select(margin=(20, 20, 20, 20), name='mouse', options=['Cori', 'Muller', ...], value='Cori', width=250)

# %% [markdown]
# The dashboard looks a little crowded. It would help if we treated combination of histogram plots as one component and scatter plot as another.
#
# **Example** Plot the two histograms side-by-side and the scatter plot below them

# %%
plot_1 = df.hvplot.hist('response_time', groupby='mouse')
plot_2 = df.hvplot.hist('feedback_time', groupby='mouse')
plot_3 = df.hvplot.scatter('feedback_time', 'response_time', groupby='mouse')
hist = pn.Row(plot_1, plot_2) 
viz = pn.Column(hist, plot_3)
viz
# Out:
# Column
#     [0] Row
#         [0] Row
#             [0] HoloViews(DynamicMap, height=300, sizing_mode='fixed', width=700)
#             [1] WidgetBox(align=('end', 'start'))
#                 [0] Select(margin=(20, 20, 20, 20), name='mouse', options=['Cori', 'Muller', ...], value='Cori', width=250)
#         [1] Row
#             [0] HoloViews(DynamicMap, height=300, sizing_mode='fixed', width=700)
#             [1] WidgetBox(align=('end', 'start'))
#                 [0] Select(margin=(20, 20, 20, 20), name='mouse', options=['Cori', 'Muller', ...], value='Cori', width=250)
#     [1] Row
#         [0] HoloViews(DynamicMap, height=300, sizing_mode='fixed', width=700)
#         [1] WidgetBox(align=('end', 'start'))
#             [0] Select(margin=(20, 20, 20, 20), name='mouse', options=['Cori', 'Muller', ...], value='Cori', width=250)

# %% [markdown]
# Plot the two histograms side-by-side and the scatter plot above them

# %%
plot_1 = df.hvplot.hist('response_time', groupby='mouse')
plot_2 = df.hvplot.hist('feedback_time', groupby='mouse')
plot_3 = df.hvplot.scatter('feedback_time', 'response_time', groupby='mouse')
hist = pn.Row(plot_1, plot_2) 
viz = pn.Column(plot_3, hist)
viz
# Out:
# Column
#     [0] Row
#         [0] HoloViews(DynamicMap, height=300, sizing_mode='fixed', width=700)
#         [1] WidgetBox(align=('end', 'start'))
#             [0] Select(margin=(20, 20, 20, 20), name='mouse', options=['Cori', 'Muller', ...], value='Cori', width=250)
#     [1] Row
#         [0] Row
#             [0] HoloViews(DynamicMap, height=300, sizing_mode='fixed', width=700)
#             [1] WidgetBox(align=('end', 'start'))
#                 [0] Select(margin=(20, 20, 20, 20), name='mouse', options=['Cori', 'Muller', ...], value='Cori', width=250)
#         [1] Row
#             [0] HoloViews(DynamicMap, height=300, sizing_mode='fixed', width=700)
#             [1] WidgetBox(align=('end', 'start'))
#                 [0] Select(margin=(20, 20, 20, 20), name='mouse', options=['Cori', 'Muller', ...], value='Cori', width=250)

# %% [markdown]
# Plot the two histograms side-by-side and the scatter plot in separate tabs

# %%
plot_1 = df.hvplot.hist('response_time', groupby='mouse')
plot_2 = df.hvplot.hist('feedback_time', groupby='mouse')
plot_3 = df.hvplot.scatter('feedback_time', 'response_time', groupby='mouse')
hist = pn.Row(plot_1, plot_2) 
viz = pn.Tabs(
    ("Histograms", hist), 
    ("Scatter Plot", plot_3)
)
viz
# Out:
# Tabs
#     [0] Row
#         [0] Row
#             [0] HoloViews(DynamicMap, height=300, sizing_mode='fixed', width=700)
#             [1] WidgetBox(align=('end', 'start'))
#                 [0] Select(margin=(20, 20, 20, 20), name='mouse', options=['Cori', 'Muller', ...], value='Cori', width=250)
#         [1] Row
#             [0] HoloViews(DynamicMap, height=300, sizing_mode='fixed', width=700)
#             [1] WidgetBox(align=('end', 'start'))
#                 [0] Select(margin=(20, 20, 20, 20), name='mouse', options=['Cori', 'Muller', ...], value='Cori', width=250)
#     [1] Row
#         [0] HoloViews(DynamicMap, height=300, name='Scatter Plot', sizing_mode='fixed', width=700)
#         [1] WidgetBox(align=('end', 'start'))
#             [0] Select(margin=(20, 20, 20, 20), name='mouse', options=['Cori', 'Muller', ...], value='Cori', width=250)

# %%
pn.serve(viz);
# Out:
# Launching server at http://localhost:51114

# %% [markdown]
# ## Getting More Control over Interactive Widgets
#
# In the previous section, we used panel only for arrangement of our interactive visual components. The interactive options from hvplot alone can be quite limited. However, panel also provides interactive widgets that can be combined with hvplot figures to give us more control over the kind of interactive widgets that can be used for the dashboard. And as always, they can be tried and tested out in Jupyter notebook before implementing as web app.
#
# In this section, we will follow the similar approach as the other two sections where we will test out single visualization, smaller combinations, and a larger layout but by adding more interactive options using panel.

# %% [markdown]
# One of the requirements of your dashboard is that your collaborators has an option to see a certain number of rows of your data. So let's try out a few of them and see which one would look best on a dashboard.
#
# **Example** use a slider to start from no rows to full length of dataset

# %%
interactive_df = df.interactive()
slider = pnw.IntSlider(name='Num Rows', start
}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.widgets.CustomSelect","id":"0fa5554d-5b4f-4425-8b2c-458c9e063ea4","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"7093ae7c-afe0-41a4-9908-fb022a51bfb8"},{"type":"object","name":"ImportedStyleSheet","id":"e4ada09c-29ac-4501-ac8a-919d6fbf7c54","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.8/dist/css/select.css"}},{"id":"98b059f5-c7da-45b4-8a30-0f82011a3475"},{"id":"5f04b711-50f2-446f-bdb0-10c11e96b121"}],"width":300,"min_width":300,"margin":[5,10],"align":"start","title":"Select","options":["response_time","feedback_time"],"value":"response_time"}}]}},{"type":"object","name":"panel.models.layout.Column","id":"66937011-cd0c-4153-9409-6c246499f440","attributes":{"name":"Column63990","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"7093ae7c-afe0-41a4-9908-fb022a51bfb8"},{"id":"88350150-08e0-4f2c-b4e3-1f4c04fbad35"},{"id":"98b059f5-c7da-45b4-8a30-0f82011a3475"},{"id":"5f04b711-50f2-446f-bdb0-10c11e96b121"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.markup.HTML","id":"1c2a9855-797d-4cca-b3ba-175b8eaef5bd","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"7093ae7c-afe0-41a4-9908-fb022a51bfb8"},{"type":"object","name":"ImportedStyleSheet","id":"ac78770b-a193-4d0b-b8c6-5384e72 ...

# %% [markdown]
# Display the options as slider.

# %%
interactive_df = df.interactive()
select = pnw.DiscreteSlider(name='Select', options=['response_time', 'feedback_time'])
stats = interactive_df[select].describe()
stats
# Out:
# <div id='d8244af0-46ab-45b9-ac2f-c7ef69333bb7'>
#   <div id="d226bcda-e356-476c-973d-bd9bcf83282c" data-root-id="d8244af0-46ab-45b9-ac2f-c7ef69333bb7" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"85bd9638-33cd-4807-92fc-c998de0c72e8":{"version":"3.3.4","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"d8244af0-46ab-45b9-ac2f-c7ef69333bb7","attributes":{"name":"Row69795","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"4ad120d7-93fc-495e-bf72-0a7736dacdeb","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.8/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"af479abc-4383-4812-b584-f1bd94466ef7","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.8/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"5fbff034-0998-413a-aa9d-a873514b3279","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.8/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"7bcd70d3-c189-4e4e-afe1-a054d1c4595f","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.8/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"c96239a8-9517-49b2-9281-6cea6e050510","attributes":{"name":"Column69794","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"4ad120d7-93fc-495e-bf72-0a7736dacdeb"},{"id":"af479abc-4383-4812-b584-f1bd94466ef7"},{"id":"5fbff034-0998-413a-aa9d-a873514b3279"},{"id":"7bcd70d3-c189-4e4e-afe1-a054d1c4595f"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"36bd46d7-d8c0-4e3b-8211-36f70c0c969f","attributes":{"name":"Column69786","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"4ad120d7-93fc-495e-bf72-0a7736dacdeb"},{"id":"af479abc-4383-4812-b584-f1bd94466ef7"},{"id":"5fbff034-0998-413a-aa9d-a873514b3279"},{"id":"7bcd70d3-c189-4e4e-afe1-a054d1c4595f"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"99d8b1fa-d393-4f72-84f7-c7437ace5cda","attributes":{"name":"Column69677","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"4ad120d7-93fc-495e-bf72-0a7736dacdeb"},{"id":"af479abc-4383-4812-b584-f1bd94466ef7"},{"id":"5fbff034-0998-413a-aa9d-a873514b3279"},{"id":"7bcd70d3-c189-4e4e-afe1-a054d1c4595f"}],"margin":0,"align":"start","children":[{"type":"object","name":"Div","id":"4e8c8465-d8f1-4f97-9af2-15727a96b547","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"4ad120d7-93fc-495e-bf72-0a7736dacdeb"},{"id":"5fbff034-0998-413a-aa9d-a873514b3279"},{"id":"7bcd70d3-c189-4e4e-afe1-a054d1c4595f"}],"margin":[5,0,0,10],"align":"start","text":"Select: <b>response_time</b>"}},{"type":"object","name":"Slider","id":"17510637-cba5-44f4-970e-7a1faeabbfea","attributes":{"js_property_callbacks":{"type":"map","entries":[["change:value",[{"type":"object","name":"CustomJS","id":"f6277805-f4de-4796-8723-bf54e47852a3","attributes":{"tags":[[2135408530320,[null,"value"],[null,null]]],"args":{"type":"map","entries":[["bidirectional",false],["properties",{"type":"map"}],["source",{"id":"17510637-cba5-44f4-970e-7a1faeabbfea"}],["target",{"id":"4e8c8465-d8f1-4f97-9af2-15727a96b547"}]]},"code":"try { \n    var labels = ['Select: <b>response_time</b>', 'Select: <b>feedback_time</b>']\n    target.text = labels[source.value]\n     } catch(err) { console.log(err) }"}}]]]},"stylesheets": ...

# %% [markdown]
# That does not look suitable for this purpose.
#
# Display the options as radio buttons

# %%
interactive_df = df.interactive()
radio_button_group = pnw.RadioButtonGroup(name='Select', options=['response_time', 'feedback_time'])
stats = interactive_df[radio_button_group].describe()
stats
# Out:
# <div id='07bd43a0-61d2-464e-a5cc-b8a3286d2829'>
#   <div id="e9bdb7ff-4ee2-4ad2-b66b-f3d05ca673d2" data-root-id="07bd43a0-61d2-464e-a5cc-b8a3286d2829" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"d576edcb-16da-419f-99c2-3de78ab1f832":{"version":"3.3.4","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"07bd43a0-61d2-464e-a5cc-b8a3286d2829","attributes":{"name":"Row68582","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"2e296937-09bd-4b36-ae0f-ac51aeed5f43","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.8/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"d81df066-84f9-4d2f-8cda-a988a46bb85c","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.8/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"a72cb377-96ab-4231-ae61-b05c6dd49a0e","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.8/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"b87cfb9d-8557-4b0b-b680-b18c2ef778bc","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.8/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"7f04fce4-74e8-42ba-9cd3-a309a03b088e","attributes":{"name":"Column68581","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"2e296937-09bd-4b36-ae0f-ac51aeed5f43"},{"id":"d81df066-84f9-4d2f-8cda-a988a46bb85c"},{"id":"a72cb377-96ab-4231-ae61-b05c6dd49a0e"},{"id":"b87cfb9d-8557-4b0b-b680-b18c2ef778bc"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"702c2e51-5af6-4c54-bbb1-5fdb90617d30","attributes":{"name":"Column68573","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"2e296937-09bd-4b36-ae0f-ac51aeed5f43"},{"id":"d81df066-84f9-4d2f-8cda-a988a46bb85c"},{"id":"a72cb377-96ab-4231-ae61-b05c6dd49a0e"},{"id":"b87cfb9d-8557-4b0b-b680-b18c2ef778bc"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.widgets.RadioButtonGroup","id":"cbac97af-e011-49de-a13e-5befa43c6450","attributes":{"css_classes":["solid"],"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"2e296937-09bd-4b36-ae0f-ac51aeed5f43"},{"type":"object","name":"ImportedStyleSheet","id":"c636956d-9822-44fc-8122-93880744d272","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.8/dist/css/button.css"}},{"id":"a72cb377-96ab-4231-ae61-b05c6dd49a0e"},{"id":"b87cfb9d-8557-4b0b-b680-b18c2ef778bc"}],"margin":[5,10],"align":"start","labels":["response_time","feedback_time"],"active":0}}]}},{"type":"object","name":"panel.models.layout.Column","id":"642eba55-4408-4709-b197-477eecfdd950","attributes":{"name":"Column68578","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"2e296937-09bd-4b36-ae0f-ac51aeed5f43"},{"id":"d81df066-84f9-4d2f-8cda-a988a46bb85c"},{"id":"a72cb377-96ab-4231-ae61-b05c6dd49a0e"},{"id":"b87cfb9d-8557-4b0b-b680-b18c2ef778bc"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.markup.HTML","id":"21f2a0df-1d5b-4c5a-ba26-492b5cf4e882","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"2e296937-09bd-4b36-ae0f-ac51aeed5f43"},{"type":"object","name":"ImportedStyleSheet","id":"cb375af1-3b97-49d9-b11c-128c614fb612","attributes":{"url":"htt ...

# %% [markdown]
# Now only figures are remaining. You need to arrange all these in a layout along with box plots when response time or feedback time are selected. Let's try out as usual, different ways of arranging them.
#
# **Example** Arrange data, stats, and plot side by side

# %%
interactive_df = df.interactive()
slider = pnw.IntSlider(name='Num Rows', start=3, end=10)
radio_button_group = pnw.RadioButtonGroup(name='Select', options=['response_time', 'feedback_time'])
table = interactive_df.head(slider)
stats = interactive_df[radio_button_group].describe()
plot = interactive_df[radio_button_group].hvplot.box()

layout = pn.Row(table, stats, plot)
layout
# Out:
# Row
#     [0] Interactive(Interactive)
#     [1] Interactive(Interactive)
#     [2] Interactive(Interactive)

# %% [markdown]
# Arrange them one above the other

# %%
interactive_df = df.interactive()
slider = pnw.IntSlider(name='Num Rows', start=3, end=10)
radio_button_group = pnw.RadioButtonGroup(name='Select', options=['response_time', 'feedback_time'])
table = interactive_df.head(slider)
stats = interactive_df[radio_button_group].describe()
plot = interactive_df[radio_button_group].hvplot.box()

layout = pn.Column(table, stats, plot)
layout
# Out:
# Column
#     [0] Interactive(Interactive)
#     [1] Interactive(Interactive)
#     [2] Interactive(Interactive)

# %% [markdown]
# Arrange the table one top and both the plot and stats on the bottom row

# %%
interactive_df = df.interactive()
slider = pnw.IntSlider(name='Num Rows', start=3, end=10)
radio_button_group = pnw.RadioButtonGroup(name='Select', options=['response_time', 'feedback_time'])
table = interactive_df.head(slider)
stats = interactive_df[radio_button_group].describe()
plot = interactive_df[radio_button_group].hvplot.box()

layout = pn.Column(table, pn.Row(stats, plot))
layout
# Out:
# Column
#     [0] Interactive(Interactive)
#     [1] Row
#         [0] Interactive(Interactive)
#         [1] Interactive(Interactive)

# %% [markdown]
# Serve it in web app and see the whole thing

# %%
pn.serve(layout);
# Out:
# Launching server at http://localhost:62539

# %% [markdown]
# ## Panel has many other widgets (Demo)

# %% [markdown]
# With check box

# %%
# Define widgets
checkbox = pn.widgets.Checkbox(name='Line Plot', value=True)

@pn.depends(checkbox.param.value)
def checkbox_plot(value):
    plot_type = 'line' if value else 'scatter'
    return df.hvplot(x='response_time', y='feedback_time', kind=plot_type).opts(title=f"Line Plot? {value}")

layout = pn.Row(checkbox, checkbox_plot)
layout
# Out:
# Row
#     [0] Checkbox(name='Line Plot', value=True)
#     [1] ParamFunction(function, _pane=HoloViews, defer_load=False)

# %%
checkbox = pn.widgets.Checkbox(name='Color red', value=True)

@pn.depends(checkbox.param.value)
def checkbox_plot(value):
    color = 'r' if value else 'b'
    plot1 = df.hvplot(x='response_time', y='feedback_time', kind='scatter', color=color).opts(title=f"Color Red? {value}")
    plot2 = df.hvplot(x='response_time', y='reaction_time', kind='scatter', color=color).opts(title=f"Color Red? {value}")
    return (plot1 + plot2).opts(shared_axes=False)

layout = pn.Row(checkbox, checkbox_plot)
layout
# Out:
# Row
#     [0] Checkbox(name='Color red', value=True)
#     [1] ParamFunction(function, _pane=HoloViews, defer_load=False)
